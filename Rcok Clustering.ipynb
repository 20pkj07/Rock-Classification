# %% [markdown]
# <a href="https://colab.research.google.com/github/20pkj07/Rock-Classification/blob/main/Rcok%20Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name               : Pankaj Kumar
#
# # Admission no : 20JE0659
#
# ### Q.1  K-means Clustering algorithm

# %%
#importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
import numpy as np

# %%
#loading data
df=pd.read_csv("logdata-3.dat")
df
# Out:
#       density(g/cc)  porosity(%)  Gamma(API)  sonic(ms/m  resistivity(ohm-m)
# 0              2.75        7.000    109.9472    176.3300              7.0639
# 1              2.80       19.000    134.2898    211.3802              5.5186
# 2              2.90       25.000      4.4817    161.0000              8.8060
# 3              2.95       17.000      7.3891    160.3401              9.1018
# 4              3.00       20.000     20.0855    159.5900              9.2303
# ...             ...          ...         ...         ...                 ...
# 1395           2.44       11.644     42.0000    246.6299              4.1882
# 1396           2.55       11.907     43.0000    272.7501              4.2463
# 1397           2.20       12.340     44.0000    296.7500              4.4349
# 1398           2.70       12.810     45.0000    312.9999              4.5614
# 1399           2.67       13.345     46.0000    309.9999              4.5326
#
# [1400 rows x 5 columns]

# %%
df.describe()
# Out:
#        density(g/cc)  porosity(%)   Gamma(API)   sonic(ms/m  \
# count    1400.000000  1400.000000  1400.000000  1400.000000
# mean        2.693811    17.502491    67.384901   172.428327
# std         0.329322     9.855991    38.571237    25.793440
# min         1.000000     3.000000     2.718300   147.450000
# 25%         2.650000    11.250250    33.115500   158.460000
# 50%         2.757300    16.000000    58.035000   165.520000
# 75%         2.864900    20.206000   101.494000   171.552475
# max         3.300000    85.000000   190.566300   312.999900
#
#        resistivity(ohm-m)
# count         1400.000000
# mean             7.910179
# std              1.687288
# min              4.188200
# 25%              7.011000
# 50%              7.816200
# 75%              9.006000
# max             12.811300

# %%
df.isnull().sum()
# Out:
# density(g/cc)         0
# porosity(%)           0
# Gamma(API)            0
# sonic(ms/m            0
# resistivity(ohm-m)    0
# dtype: int64

# %%
#plotting scatter plot
sns.set(font_scale=1.5)
plt.figure(figsize=(20,20))
sns.pairplot(df[:-1])
plt.show()

# %%
#corelation
plt.figure(figsize=(10,8))
sns.heatmap(data=df.corr())
# Out:
# <AxesSubplot:>

# %%
# Creating the KMeans object
# 3 cluster
km3 = KMeans(n_clusters=3, max_iter=15, tol=0.0001)

# Fitting the KMeans model to the data
km3.fit(df)

# Printting the cluster centers and error for 15 iteration
print("\nCenters   :\n\n",km3.cluster_centers_)
print("\n Error  : ",km3.inertia_)
print('\n')
# Out:
# Centers   :
#
#  [[  2.73826877  19.35382677  40.83091942 158.89792625   8.87319869]
#  [  2.69435695  12.7461565  116.04326996 172.09941525   7.46431525]
#  [  2.51610104  21.20357292  59.74168125 226.89114323   5.12390104]]
#
#  Error  :  820976.6114171587

# %%
#predicting data
y=km3.fit_predict(df)
y
# Out:
# array([0, 0, 1, ..., 2, 2, 2])

# %%
df2=df
df2['Target']=y
df2
# Out:
#       density(g/cc)  porosity(%)  Gamma(API)  sonic(ms/m  resistivity(ohm-m)  \
# 0              2.75        7.000    109.9472    176.3300              7.0639
# 1              2.80       19.000    134.2898    211.3802              5.5186
# 2              2.90       25.000      4.4817    161.0000              8.8060
# 3              2.95       17.000      7.3891    160.3401              9.1018
# 4              3.00       20.000     20.0855    159.5900              9.2303
# ...             ...          ...         ...         ...                 ...
# 1395           2.44       11.644     42.0000    246.6299              4.1882
# 1396           2.55       11.907     43.0000    272.7501              4.2463
# 1397           2.20       12.340     44.0000    296.7500              4.4349
# 1398           2.70       12.810     45.0000    312.9999              4.5614
# 1399           2.67       13.345     46.0000    309.9999              4.5326
#
#       Target
# 0          0
# 1          0
# ...

# %%
#plotting scatter plot
plt.figure(figsize=(20,20))
sns.pairplot(df2[:-1],hue='Target',palette='Accent')
plt.show()

# %%
#counting no. of target
df2['Target'].value_counts()
# Out:
# 1    762
# 0    446
# 2    192
# Name: Target, dtype: int64

# %%
# Creating the KMeans object
# 2 cluster
km2 = KMeans(n_clusters=2, max_iter=15, tol=0.0001)

# Fitting the KMeans model to the data
km2.fit(df)

# Printting the cluster centers and error for 15 iteration
print("\nCenters   :\n\n",km2.cluster_centers_)
print("\n Error  : ",km2.inertia_)
print('\n')
# Out:
# Centers   :
#
#  [[2.68877053e+00 1.96325411e+01 4.44172733e+01 1.72104315e+02
#   8.14413874e+00 1.18526316e+00]
#  [2.70445200e+00 1.30057196e+01 1.15872116e+02 1.73112354e+02
#   7.41626489e+00 4.44444444e-02]]
#
#  Error  :  1579361.672176625

# %%
x=km2.fit_predict(df)
df3=df
df3['Target']=x
df3
# Out:
#       density(g/cc)  porosity(%)  Gamma(API)  sonic(ms/m  resistivity(ohm-m)  \
# 0              2.75        7.000    109.9472    176.3300              7.0639
# 1              2.80       19.000    134.2898    211.3802              5.5186
# 2              2.90       25.000      4.4817    161.0000              8.8060
# 3              2.95       17.000      7.3891    160.3401              9.1018
# 4              3.00       20.000     20.0855    159.5900              9.2303
# ...             ...          ...         ...         ...                 ...
# 1395           2.44       11.644     42.0000    246.6299              4.1882
# 1396           2.55       11.907     43.0000    272.7501              4.2463
# 1397           2.20       12.340     44.0000    296.7500              4.4349
# 1398           2.70       12.810     45.0000    312.9999              4.5614
# 1399           2.67       13.345     46.0000    309.9999              4.5326
#
#       Target
# 0          0
# 1          0
# ...

# %%
#plotting scatter plot
plt.figure(figsize=(20,20))
sns.pairplot(df3[:-1],hue='Target',palette='RdBu')
plt.show()

# %%
#counting no. of target
df3['Target'].value_counts()
# Out:
# 1    950
# 0    450
# Name: Target, dtype: int64
